# %%
import nltk, csv
from nltk import pos_tag, ne_chunk

# A function to extract place names
def extract_place_names(input_file):
    print(f"Opening and reading file: {input_file}")
    with open(input_file, 'r') as f:
        text = f.read().split()

    print("Tagging parts of speech...")
    pos_tags = pos_tag(text)

    print("Performing named entity recognition...")
    named_entities = ne_chunk(pos_tags)

    # Extract and print the place names
    print("Extracting place names...")
    place_names = []
    for entity in named_entities:
        if isinstance(entity, nltk.tree.Tree) and entity.label() == 'GPE':
            place_names.append(' '.join([word for word, tag in entity.leaves()]))

    return place_names

# Define a function to write output to a CSV file
def write_to_csv(filename, data):
    with open(filename, 'w', newline='') as f:
        writer = csv.writer(f)
        for item in data:
            # write each item in data to a new row
            writer.writerow([item])

# Test the function, against your desired source
print("Starting place name extraction test...")
place_names = extract_place_names('../output/tokenized_merged_titles.txt')
print(place_names)
write_to_csv('../output/tokenized_merged_titles_test_output.csv', place_names)
print("Place name extraction test complete. See results in output/tokenized_merged_titles_test_output.csv\n")

# Run the function, against your desired source
print("Starting place name extraction job...")
place_names = extract_place_names('../output/tokenized_merged_titles.txt')
print(place_names)
write_to_csv('../output/extracted_entities_tokenized_merged_titles.csv', place_names)
print("Place name extraction job complete. See results in output/extracted_entities_tokenized_merged_titles.csv\n")
# Out:
# Starting place name extraction test...
# Opening and reading file: ../output/tokenized_merged_titles.txt
# Tagging parts of speech...
# Performing named entity recognition...
# Extracting place names...
# ['Munich', 'England', 'English', 'Leicestershire', 'Munich', 'Germany', 'Germans', 'English', 'English', 'Heines', 'Munich', 'Munich', 'German', 'Munich', 'Heines', 'England', 'Munich', 'Munich', 'English', 'England', 'English', 'Munich', 'English', 'German', 'English', 'English', 'German', 'English', 'Munich', 'New', 'Isa', 'New', 'England', 'English', 'English', 'England', 'Isa', 'Isa', 'London', 'Cheery', 'Isa', 'Niece', 'Bavaria', 'Bavaria', 'English', 'Berkshire', 'Rome', 'Rome', 'English', 'British', 'Rome', 'English', 'Americans', 'Italian', 'American', 'Rome', 'Rome', 'Mackinnon', 'Mackinnon', 'English', 'Ireland', 'Mackinnon', 'Rome', 'Cherub', 'Campidoglio', 'Pollux', 'Castor', 'Mackinnon', 'American', 'English', 'Mackinnon', 'Campidoglio', 'French', 'Mackinnon', 'Rome', 'Praetorian', 'French', 'Italia', 'Italia', 'Bourbons', 'Europe', 'Mackinnon', 'Magenta', 'Italy', 'Rome', 'Mackinnon', 'Rome', 'Italy', 'American', 'Italy', 'Browns', 'Mackinnon', 'Appian Way', 'Rome', 'Palestrina', 'Rome', 'Rome', 'Coliseum', 'Mackinnon', 'England', 'Irish', 'Frangipani', 'Italy', 'Udolpho', 'Roman', 'Claudian', 'Tivoli', 'Palestine', 'Frascati', 'Roman', 'Crassus', 'Falernian', 'Samian', 'Falernian', 'Egeria', 'Mackinnon', 'Naples', 'Italy', 'Naples', 'Irish', 'Spartan', 'Rome', 'England', 'Punch', 'Mackinnon', 'Naples', 'Mackinnon', 'Rome', 'Rome', 'London', 'Suez', 'Egypt', 'Egypt', 'Cairo', 'St.', 'Cairo', 'Suez', 'Cairo', 'British', 'Egypt', 'Cairo', 'India', 'Australia', 'Holloa', 'Sise Lane', 'Australia', 'Cairo', 'Australian', 'Suez', 'England', 'Egypt', 'Cairo', 'Suez', 'Cairo', 'Suez', 'England', 'Eastern', 'Suez', 'Egypt', 'Egypt', 'Cairo', 'Suez', 'Cairo', 'Egypt', 'Eastern', 'Turks', 'Copts', 'Christian', 'Egypt', 'Christian', 'Christian', 'Christian', 'Christian', 'Cairo', 'Grimes', 'French', 'French', 'French', 'French', 'French', 'English', 'Italian', 'Turkish', 'Armenian', 'German', 'English', 'English', 'Christian', 'Christian', 'Italian', 'Trieste', 'Austrian', 'English', 'Ackbar', 'Italian', 'English', 'Mahmoud', 'Egypt', 'Moses', 'Asia', 'Moses', 'Moses', 'Asia', 'Suez', 'Suez', 'Mahmoud', 'Cairo', 'Mahmoud', 'Asia', 'Moses', 'Frank', 'English', 'Cairo', 'Austrian', 'English', 'Grimes', 'Pegu', 'Pegu', 'India', 'India', 'Begum', 'Ackbar', 'Moses', 'Moses', 'Asia', 'Africa', 'English', 'Pegu', 'Ackbar', 'Begum', 'Pegu', 'Asia', 'Africa', 'Greene', 'Switzerland', 'Switzerland', 'Italy', 'Austrian', 'United Italy', 'Greenes', 'Italian', 'Italy', 'Italian', 'Italian', 'Muddleboro', 'English', 'Italian', 'French', 'English', 'Greene', 'Irish', 'Italy', 'England', 'English', 'London', 'England', 'Colico', 'Lecco', 'Bellaggio', 'Italy', 'England', 'Greene', 'Freidrichshafen', 'Teutonic', 'Colico', 'Greene', 'Italian', 'Colico', 'Colico', '—and', 'English', 'Bellaggio', 'Bellaggio', 'Greene', 'Greene', 'English', 'Bellaggio', 'English', 'French', 'French', 'German', 'England', 'Bellaggio', 'Italians', 'English', 'Sophonisba', 'Sophonisba', 'Greene', 'Italian', 'Greene', 'Greene', 'Sophonisba', 'Greene', 'Greene', 'Italian', 'English', 'French', 'England', 'Venice', 'England', 'England', 'Greene', 'Greenes', 'Greene', 'Greene', 'Greenes', 'Bellaggio', 'Greenes', 'English', 'Italian', 'French', 'English', 'Greene', 'Italian', 'Boots', 'Colico', 'Venice', 'Florence', 'Bellaggio', 'Boots', 'Greene', 'Venice', 'Greenes', 'Greene', 'Greene', 'Sophonisba', 'Venice', 'British', 'London', 'Greene', 'London', 'Boots', 'Boots', 'Sophonisba', 'England', 'Italy', 'Venice', 'Greene', 'Greene', 'Milan', 'Boots', 'Greene', 'Italian', 'Greene', 'Greene', 'Bellaggio', 'Greenes', 'Greene', 'Greene', 'Greene', 'Greene', 'Boots', 'Greenes', 'Italian', 'Verona', 'Innspruck', 'England', 'Goshen', 'Barsetshire', 'East Barsetshire', 'Peelism', 'Omnium', 'East', 'Greshamsbury', 'East Barsetshire', 'Courcy', 'East Barsetshire', 'Dragon', 'Gresham', 'England', 'English', 'English', 'England', 'Parliament', 'East Barsetshire', 'Lords', 'Greshamsbu ...
# Place name extraction test complete. See results in output/tokenized_merged_titles_test_output.csv
#
# Starting place name extraction job...
# Opening and reading file: ../output/tokenized_merged_titles.txt
# Tagging parts of speech...
# Performing named entity recognition...
# Extracting place names...
# ['Munich', 'England', 'English', 'Leicestershire', 'Munich', 'Germany', 'Germans', 'English', 'English', 'Heines', 'Munich', 'Munich', 'German', 'Munich', 'Heines', 'England', 'Munich', 'Munich', 'English', 'England', 'English', 'Munich', 'English', 'German', 'English', 'English', 'German', 'English', 'Munich', 'New', 'Isa', 'New', 'England', 'English', 'English', 'England', 'Isa', 'Isa', 'London', 'Cheery', 'Isa', 'Niece', 'Bavaria', 'Bavaria', 'English', 'Berkshire', 'Rome', 'Rome', 'English', 'British', 'Rome', 'English', 'Americans', 'Italian', 'American', 'Rome', 'Rome', 'Mackinnon', 'Mackinnon', 'English', 'Ireland', 'Mackinnon', 'Rome', 'Cherub', 'Campidoglio', 'Pollux', 'Castor', 'Mackinnon', 'American', 'English', 'Mackinnon', 'Campidoglio', 'French', 'Mackinnon', 'Rome', 'Praetorian', 'French', 'Italia', 'Italia', 'Bourbons', 'Europe', 'Mackinnon', 'Magenta', 'Italy', 'Rome', 'Mackinnon', 'Rome', 'Italy', 'American', 'Italy', 'Browns', 'Mackinnon', 'Appian Way', 'Rome', 'Palestrina', 'Rome', 'Rome', 'Coliseum', 'Mackinnon', 'England', 'Irish', 'Frangipani', 'Italy', 'Udolpho', 'Roman', 'Claudian', 'Tivoli', 'Palestine', 'Frascati', 'Roman', 'Crassus', 'Falernian', 'Samian', 'Falernian', 'Egeria', 'Mackinnon', 'Naples', 'Italy', 'Naples', 'Irish', 'Spartan', 'Rome', 'England', 'Punch', 'Mackinnon', 'Naples', 'Mackinnon', 'Rome', 'Rome', 'London', 'Suez', 'Egypt', 'Egypt', 'Cairo', 'St.', 'Cairo', 'Suez', 'Cairo', 'British', 'Egypt', 'Cairo', 'India', 'Australia', 'Holloa', 'Sise Lane', 'Australia', 'Cairo', 'Australian', 'Suez', 'England', 'Egypt', 'Cairo', 'Suez', 'Cairo', 'Suez', 'England', 'Eastern', 'Suez', 'Egypt', 'Egypt', 'Cairo', 'Suez', 'Cairo', 'Egypt', 'Eastern', 'Turks', 'Copts', 'Christian', 'Egypt', 'Christian', 'Christian', 'Christian', 'Christian', 'Cairo', 'Grimes', 'French', 'French', 'French', 'French', 'French', 'English', 'Italian', 'Turkish', 'Armenian', 'German', 'English', 'English', 'Christian', 'Christian', 'Italian', 'Trieste', 'Austrian', 'English', 'Ackbar', 'Italian', 'English', 'Mahmoud', 'Egypt', 'Moses', 'Asia', 'Moses', 'Moses', 'Asia', 'Suez', 'Suez', 'Mahmoud', 'Cairo', 'Mahmoud', 'Asia', 'Moses', 'Frank', 'English', 'Cairo', 'Austrian', 'English', 'Grimes', 'Pegu', 'Pegu', 'India', 'India', 'Begum', 'Ackbar', 'Moses', 'Moses', 'Asia', 'Africa', 'English', 'Pegu', 'Ackbar', 'Begum', 'Pegu', 'Asia', 'Africa', 'Greene', 'Switzerland', 'Switzerland', 'Italy', 'Austrian', 'United Italy', 'Greenes', 'Italian', 'Italy', 'Italian', 'Italian', 'Muddleboro', 'English', 'Italian', 'French', 'English', 'Greene', 'Irish', 'Italy', 'England', 'English', 'London', 'England', 'Colico', 'Lecco', 'Bellaggio', 'Italy', 'England', 'Greene', 'Freidrichshafen', 'Teutonic', 'Colico', 'Greene', 'Italian', 'Colico', 'Colico', '—and', 'English', 'Bellaggio', 'Bellaggio', 'Greene', 'Greene', 'English', 'Bellaggio', 'English', 'French', 'French', 'German', 'England', 'Bellaggio', 'Italians', 'English', 'Sophonisba', 'Sophonisba', 'Greene', 'Italian', 'Greene', 'Greene', 'Sophonisba', 'Greene', 'Greene', 'Italian', 'English', 'French', 'England', 'Venice', 'England', 'England', 'Greene', 'Greenes', 'Greene', 'Greene', 'Greenes', 'Bellaggio', 'Greenes', 'English', 'Italian', 'French', 'English', 'Greene', 'Italian', 'Boots', 'Colico', 'Venice', 'Florence', 'Bellaggio', 'Boots', 'Greene', 'Venice', 'Greenes', 'Greene', 'Greene', 'Sophonisba', 'Venice', 'British', 'London', 'Greene', 'London', 'Boots', 'Boots', 'Sophonisba', 'England', 'Italy', 'Venice', 'Greene', 'Greene', 'Milan', 'Boots', 'Greene', 'Italian', 'Greene', 'Greene', 'Bellaggio', 'Greenes', 'Greene', 'Greene', 'Greene', 'Greene', 'Boots', 'Greenes', 'Italian', 'Verona', 'Innspruck', 'England', 'Goshen', 'Barsetshire', 'East Barsetshire', 'Peelism', 'Omnium', 'East', 'Greshamsbury', 'East Barsetshire', 'Courcy', 'East Barsetshire', 'Dragon', 'Gresham', 'England', 'English', 'English', 'England', 'Parliament', 'East Barsetshire', 'Lords', 'Greshamsbu ...
# Place name extraction job complete. See results in output/extracted_entities_tokenized_merged_titles.csv
